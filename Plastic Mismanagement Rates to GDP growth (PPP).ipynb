# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import geopandas as gpd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

gdpDF = pd.read_csv("/Users/newowner/Desktop/data/gdp.csv",encoding = 'unicode_escape')[["Country Name","2010"]]
plasticDF = pd.read_csv("/Users/newowner/Desktop/data/badplasticmanage.csv")[["Entity","Share of plastic inadequately managed (%)"]]

# %%
mergedGDPPlastic = pd.merge(left=plasticDF, right=gdpDF,left_on="Entity", right_on = "Country Name")
mergedGDPPlastic
# Out:
#                         Entity  Share of plastic inadequately managed (%)  \
# 0                      Albania                                         45
# 1                      Algeria                                         58
# 2                       Angola                                         71
# 3          Antigua and Barbuda                                          6
# 4                    Argentina                                         12
# 5                        Aruba                                          1
# 6                    Australia                                          0
# 7                      Bahrain                                         10
# 8                   Bangladesh                                         87
# 9                     Barbados                                          4
# 10                     Belgium                                          0
# 11                      Belize                                         29
# ...

# %%
mergedGDPPlastic['Ratio'] = mergedGDPPlastic['2010']/mergedGDPPlastic['Share of plastic inadequately managed (%)']
mergedGDPPlastic
# Out:
#                         Entity  Share of plastic inadequately managed (%)  \
# 0                      Albania                                         45
# 1                      Algeria                                         58
# 2                       Angola                                         71
# 3          Antigua and Barbuda                                          6
# 4                    Argentina                                         12
# 5                        Aruba                                          1
# 6                    Australia                                          0
# 7                      Bahrain                                         10
# 8                   Bangladesh                                         87
# 9                     Barbados                                          4
# 10                     Belgium                                          0
# 11                      Belize                                         29
# ...

# %%
plt.style.use('ggplot')
mergedGDPPlastic[['Ratio']].plot()
